# %% [markdown]
# # TD3-Portfoliomanagement für den Dow Jones 30
#
# Dieses Notebook zeigt, wie sich mit dem FinRL-Framework und dem TD3-Algorithmus (Twin Delayed DDPG) eine dynamische Portfolio-Allokation für den Dow Jones 30 aufbauen lässt. Alle Abschnitte sind kommentiert, um auch Einsteiger*innen bei jedem Schritt mitzunehmen.

# %% [markdown]
# ## Virtuelle Umgebung (.venv)
#
# 1. **Anlegen:** Im Projektordner `python3 -m venv .venv` ausführen (bereits für dich eingerichtet).
# 2. **Aktivieren (macOS/Linux):** `source .venv/bin/activate`
# 3. **Aktivieren (Windows PowerShell):** `.venv\\Scripts\\Activate.ps1`
# 4. **Kernel registrieren (optional, für Jupyter):**
#    ```bash
#    python -m ipykernel install --user --name drl-td3-venv --display-name "Python (.venv TD3)"
#    ```
# 5. **Pakete installieren:** Innerhalb der aktiven Umgebung die `%pip install ...`-Zelle ausführen, damit FinRL & Co. lokal isoliert bleiben.
#
# > Tipp: Bei mehreren Projekten immer das passende `.venv` aktivieren, bevor du das Notebook startest.

# %%
# Paketinstallation (ggf. beim ersten Start ausführen)
# Hinweis (Deutsch): Die Installation kann ein paar Minuten dauern.
# Achtung: FinRL wird direkt aus dem GitHub-Master installiert, da dort macOS-kompatible Abhängigkeiten gepflegt werden.
# %pip install -q "git+https://github.com/AI4Finance-Foundation/FinRL.git@master" ta
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Basisimporte und Verzeichnisse vorbereiten (Kommentare auf Deutsch)
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from finrl import config
from finrl.config import INDICATORS


from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot
from finrl.meta.preprocessor.preprocessors import FeatureEngineer

# Lokale Verzeichnisse für Zwischenergebnisse
ROOT_DIR = Path.cwd()
DATA_SAVE_DIR = ROOT_DIR / "data"
MODEL_DIR = ROOT_DIR / "models_td3"
RESULTS_DIR = ROOT_DIR / "results"
for path in (DATA_SAVE_DIR, MODEL_DIR, RESULTS_DIR):
    path.mkdir(parents=True, exist_ok=True)

# %%
DOW_30_TICKER = [
    'MMM', 'AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CVX', 'CSCO', 
    'KO', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 
    'JPM', 'MCD', 'MRK', 'MSFT', 'NKE', 'PG', 'CRM', 'TRV', 
    'UNH', 'VZ', 'V', 'WMT', 'WBA' 
]

# %%
# Dow-Jones-Konfiguration und Trainings-/Testzeiträume (Kommentare auf Deutsch)
ticker_list = DOW_30_TICKER


train_start_date = "2014-01-01"
train_end_date = "2021-12-31"
trade_start_date = "2022-01-01"
trade_end_date = "2024-11-01"

initial_capital = 1_000_000
transaction_cost_pct = 0.001  # 10 Basispunkte pro Trade
hmax = 100  # maximale Stückzahl pro Order
reward_scaling = 1e-4  
num_stock_shares = 1000

# %% [markdown]
# ## Schritt 1: Daten- und Marktparameter festlegen
#
# Wir definieren, welche Dow-Jones-30-Titel, welchen Zeitraum und welche Finanzindikatoren unser Agent für das Training und das anschließende Trading nutzen soll.

# %%
df_raw = YahooDownloader(
    start_date=train_start_date,
    end_date=trade_end_date,
    ticker_list= DOW_30_TICKER,
).fetch_data()
df_raw.to_csv('dow_30_data.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WBA']: HTTPError('HTTP Error 404: ')
# Shape of DataFrame:  (77772, 8)

# %%
df_raw
# Out:
# Price        date       close        high         low        open     volume  \
# 0      2014-01-02   17.156706   17.277674   17.122277   17.235801  234684800
# 1      2014-01-02   83.317406   83.598008   82.065482   82.281333    2528800
# 2      2014-01-02   75.593262   76.970762   75.534106   76.818646    5112000
# 3      2014-01-02  116.807961  117.303672  115.816538  116.243874    3366700
# 4      2014-01-02   66.045410   66.471648   65.648564   66.442256    4898000
# ...           ...         ...         ...         ...         ...        ...
# 77767  2024-10-31  241.938232  246.365011  241.741490  244.476254    1318600
# 77768  2024-10-31  552.517334  556.383499  548.974181  548.974181    2490000
# 77769  2024-10-31  287.259705  293.691696  287.031749  289.479677    7950200
# 77770  2024-10-31   39.416229   39.902734   38.592913   38.602267   31077900
# 77771  2024-10-31   81.158661   81.643935   80.435714   80.505038   15539000
#
# Price   tic  day
# 0      AAPL    3
# 1      AMGN    3
# 2       AXP    3
# 3        BA    3
# 4       CAT    3
# ...     ...  ...
# 77767   TRV    3
# 77768   UNH    3
# 77769     V    3
# 77770    VZ    3
# 77771   WMT    3
#
# [77772 rows x 8 columns]

# %% [markdown]
# ## Schritt 2: Datenbeschaffung & Feature Engineering
#
# Wir nutzen den integrierten `DataProcessor` von FinRL, der Yahoo Finance ansteuert, sämtliche Dow-Jones-Kurse lädt und anschließend technische Indikatoren hinzufügt.

# %%
#tech_indicators = ['rsi','macd']

fe = FeatureEngineer(
    use_technical_indicator=True,
    tech_indicator_list=INDICATORS,
    use_vix=False,        
    use_turbulence=False,  
    user_defined_feature=False
)
df = fe.preprocess_data(df_raw)

df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []


lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values 
  cov_list.append(covs)

  
df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)


df
# Out:
# Successfully added technical indicators
#              date       close        high         low        open     volume  \
# 0      2015-01-02   24.237551   24.705320   23.798600   24.694235  212818400
# 1      2015-01-02  117.267029  119.247269  116.320918  117.465056    2605400
# 2      2015-01-02   79.466217   80.252170   78.714443   79.594362    2437500
# 3      2015-01-02  113.657211  115.310248  112.905035  114.636798    4294200
# 4      2015-01-02   69.320366   69.690059   68.399922   69.237374    3767900
# ...           ...         ...         ...         ...         ...        ...
# 69295  2024-10-31  241.938232  246.365011  241.741490  244.476254    1318600
# 69296  2024-10-31  552.517334  556.383499  548.974181  548.974181    2490000
# 69297  2024-10-31  287.259705  293.691696  287.031749  289.479677    7950200
# 69298  2024-10-31   39.416229   39.902734   38.592913   38.602267   31077900
# 69299  2024-10-31   81.158661   81.643935   80.435714   80.505038   15539000
#
#         tic  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0      AAPL    4 -0.032313   25.802298   23.784588  49.712408 -117.917607
# 1      AMGN    4 -0.218230  126.512109  114.258211  52.014938  -98.288563
# 2       AXP    4  0.635426   81.914903   76.426383  54.472435   40.554814
# 3        BA    4  0.615906  118.411502  105.554005  53.311167    9.332513
# 4       CAT    4 -1.274687   74.301831   66.110407  41.395081  -68.647295
# ...     ...  ...       ...         ...         ...        ...         ...
# 69295   TRV    3  4.289557  265.811934  218.994148  55.519532   30.789545
# 69296   UNH    3 -5.253441  591.313304  534.094575  48.006190  -78.300434
# 69297     V    3  2.314701  290.740082  269.592246  57.834998  143.750873
# 69298    VZ    3 -0.360340   41.844809   38.215385  49.647300 -100.877137
# 69299   WMT    3  0.829057   82.750182   78.146991  59.957272   74.646590
#
#            dx_30  close_30_sma  close_60_sma  \
# 0      30.589492     25.154541     24.265838
# 1      26.857916    120.554460    115.278998
# 2       2.258455     78.813838     76.874452
# 3       4.733885    113.467716    110.866681
# 4      27.802444     72.634997     73.335316
# ...          ...           ...           ...
# 69295   8.858985    239.052298    230.332258
# 69296  16.237826    564.678935    567.471445
# 69297  43.150769    278.255231    275.096878
# 69298  11.875918     40.412689     39.529393
# 69299  28.968741     80.174922     77.435177
#
#                                                 cov_list  \
# 0      [[0.00018564806669213102, 5.2475743997731304e-...
# 1      [[0.00018564806669213102, 5.2475743997731304e-...
# 2      [[0.00018564806669213102, 5.2475743997731304e-...
# 3      [[0.00018564806669213102, 5.2475743997731304e-...
# 4      [[0.00018564806669213102, 5.2475743997731304e-...
# ...                                                  ...
# 69295  [[0.00020348651246347978, 5.1802428174087016e-...
# 69296  [[0.00020348651246347978, 5.1802428174087016e-...
# 69297  [[0.00020348651246347978, 5.1802428174087016e-...
# 69298  [[0.00020348651246347978, 5.1802428174087016e-...
# 69299  [[0.00020348651246347978, 5.1802428174087016e-...
#
#                                              return_list
# 0      tic             AAPL      AMGN       AXP      ...
# 1      tic             AAPL      AMGN       AXP      ...
# 2      tic             AAPL      AMGN       AXP      ...
# 3      tic             AAPL      AMGN       AXP      ...
# 4      tic             AAPL      AMGN       AXP      ...
# ...                                                  ...
# 69295  tic             AAPL      AMGN       AXP      ...
# 69296  tic             AAPL      AMGN       AXP      ...
# 69297  tic             AAPL      AMGN       AXP      ...
# 69298  tic             AAPL      AMGN       AXP      ...
# 69299  tic             AAPL      AMGN       AXP      ...
#
# [69300 rows x 18 columns]

# %%
train = data_split(df, start=train_start_date, end=train_end_date)
trade = data_split(df, start=trade_start_date, end=trade_end_date)

# %% [markdown]
# ## Schritt 3: Handelsumgebung definieren
#
# Wir erstellen zwei `StockTradingEnv`-Instanzen – eine für das Training und eine für das spätere Trading/Backtesting. Die Umgebung erhält Angaben zu Kapital, Transaktionskosten, Risiko-Kontrollen und zu den technischen Indikatoren.

# %%
stock_dim = len(train.tic.unique())

print(f"State-Dimension: {stock_dim} | Aktienanzahl: {stock_dim}")

env_kwargs = {
    "hmax": hmax,
    "initial_amount": initial_capital,
    "transaction_cost_pct": transaction_cost_pct,
    "state_space": stock_dim,
    "stock_dim": stock_dim,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dim,
    "reward_scaling": reward_scaling,
}

e_train_gym = StockPortfolioEnv(df=train, **env_kwargs)
e_trade_gym = StockPortfolioEnv(df=trade, **env_kwargs)
# Out:
# State-Dimension: 28 | Aktienanzahl: 28

# %% [markdown]
# ## Agenten konfigurieren

# %%
agent = DRLAgent(env=e_train_gym)


PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 64,
}
model_ppo = agent.get_model("ppo", model_kwargs=PPO_PARAMS)
trained_ppo = agent.train_model(model=model_ppo, 
                                tb_log_name="ppo", 
                                total_timesteps=50000
                                )
trained_ppo.save("trained_models/ppo_portfolio")

DDPG_PARAMS = {
    "batch_size": 128, 
    "buffer_size": 50000, 
    "learning_rate": 0.001
}


model_ddpg = agent.get_model("ddpg", model_kwargs=DDPG_PARAMS)
trained_ddpg = agent.train_model(model=model_ddpg, 
                                 tb_log_name="ddpg", 
                                 total_timesteps=30000
                                 )
trained_ddpg.save("trained_models/ddpg_portfolio")

TD3_PARAMS = {
    "batch_size": 100, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
}
model_td3 = agent.get_model("td3", model_kwargs=TD3_PARAMS)
trained_td3 = agent.train_model(model=model_td3, 
                                tb_log_name="td3", 
                                total_timesteps=30000
                                )
trained_td3.save("trained_models/td3_portfolio")
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# =================================
# begin_total_asset:1000000
# end_total_asset:2894929.9060965604
# Sharpe:  0.9248047753576213
# =================================
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.76e+03  |
# |    ep_rew_mean     | 2.95e+09  |
# | time/              |           |
# |    fps             | 687       |
# |    iterations      | 1         |
# |    time_elapsed    | 2         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 977040.56 |
# |    reward_max      | 2900744.0 |
# |    reward_mean     | 1582292.8 |
# |    reward_min      | 917186.94 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2850058.0084528155
# Sharpe:  0.9083555306474409
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.92e+09  |
# | time/                   |           |
# |    fps                  | 762       |
# |    iterations           | 2         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.68e+14  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -4.33e-06 |
# |    reward               | 1278887.6 |
# |    reward_max           | 2856087.8 |
# |    reward_mean          | 1571287.9 |
# |    reward_min           | 907833.44 |
# |    std                  | 1         |
# |    value_loss           | 7.79e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2971840.1640135646
# Sharpe:  0.9483032660592531
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.95e+09  |
# | time/                   |           |
# |    fps                  | 810       |
# |    iterations           | 3         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.01e+14  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -3.14e-06 |
# |    reward               | 1643351.2 |
# |    reward_max           | 2979174.8 |
# |    reward_mean          | 1687750.8 |
# |    reward_min           | 925740.0  |
# |    std                  | 1         |
# |    value_loss           | 7.62e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3025871.511911481
# Sharpe:  0.9534783450849923
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.98e+09  |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 4         |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.52e+14  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -3.36e-06 |
# |    reward               | 1979227.0 |
# |    reward_max           | 3032143.0 |
# |    reward_mean          | 1742091.5 |
# |    reward_min           | 923938.5  |
# |    std                  | 1         |
# |    value_loss           | 8.69e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2988860.7755905967
# Sharpe:  0.9505656166017977
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.99e+09  |
# | time/                   |           |
# |    fps                  | 868       |
# |    iterations           | 5         |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.93e+14  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -3.99e-06 |
# |    reward               | 2044067.4 |
# |    reward_max           | 2997814.8 |
# |    reward_mean          | 1712106.5 |
# |    reward_min           | 921086.2  |
# |    std                  | 1         |
# |    value_loss           | 9.23e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2766667.1255222657
# Sharpe:  0.8909453658408011
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.97e+09  |
# | time/                   |           |
# |    fps                  | 906       |
# |    iterations           | 6         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.02e+14  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -4.12e-06 |
# |    reward               | 2810341.0 |
# |    reward_max           | 2839144.0 |
# |    reward_mean          | 1801020.8 |
# |    reward_min           | 923308.1  |
# |    std                  | 1         |
# |    value_loss           | 8.91e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2905925.7861629026
# Sharpe:  0.9338477378608522
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2811519.170898146
# Sharpe:  0.9059488944672144
# =================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.76e+03   |
# |    ep_rew_mean          | 2.96e+09   |
# | time/                   |            |
# |    fps                  | 931        |
# |    iterations           | 7          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.0        |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -39.7      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.66e+14   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -4.54e-06  |
# |    reward               | 1034415.56 |
# |    reward_max           | 2913044.8  |
# |    reward_mean          | 1586432.5  |
# |    reward_min           | 911240.1   |
# |    std                  | 1          |
# |    value_loss           | 9.85e+14   |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2734678.4751222245
# Sharpe:  0.8829898191855373
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.95e+09  |
# | time/                   |           |
# |    fps                  | 946       |
# |    iterations           | 8         |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.41e+14  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -5.3e-06  |
# |    reward               | 1257971.0 |
# |    reward_max           | 2741578.8 |
# |    reward_mean          | 1539126.9 |
# |    reward_min           | 927708.75 |
# |    std                  | 1         |
# |    value_loss           | 7.62e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3040502.020458605
# Sharpe:  0.9660268085401484
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.96e+09  |
# | time/                   |           |
# |    fps                  | 967       |
# |    iterations           | 9         |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.33e+14  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -3.23e-06 |
# |    reward               | 1565858.5 |
# |    reward_max           | 3045305.5 |
# |    reward_mean          | 1699339.4 |
# |    reward_min           | 925104.7  |
# |    std                  | 1         |
# |    value_loss           | 7.25e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3085152.4008974545
# Sharpe:  0.9798616164110168
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.97e+09  |
# | time/                   |           |
# |    fps                  | 984       |
# |    iterations           | 10        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.94e+14  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -3.85e-06 |
# |    reward               | 1793931.9 |
# |    reward_max           | 3091711.0 |
# |    reward_mean          | 1707542.0 |
# |    reward_min           | 921860.44 |
# |    std                  | 1         |
# |    value_loss           | 8.91e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2798137.6623944705
# Sharpe:  0.9020417771803512
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.96e+09  |
# | time/                   |           |
# |    fps                  | 994       |
# |    iterations           | 11        |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.28e+14  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -4.48e-06 |
# |    reward               | 1824484.9 |
# |    reward_max           | 2822520.0 |
# |    reward_mean          | 1666833.2 |
# |    reward_min           | 930527.0  |
# |    std                  | 1         |
# |    value_loss           | 8.93e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2625668.033457325
# Sharpe:  0.8482420556482038
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.95e+09  |
# | time/                   |           |
# |    fps                  | 995       |
# |    iterations           | 12        |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.98e+14  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -4.27e-06 |
# |    reward               | 2652836.0 |
# |    reward_max           | 2689445.8 |
# |    reward_mean          | 1708778.9 |
# |    reward_min           | 939902.6  |
# |    std                  | 1         |
# |    value_loss           | 8.35e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2761900.970508657
# Sharpe:  0.8857064647507652
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2845186.5701243537
# Sharpe:  0.9120789215943736
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.94e+09  |
# | time/                   |           |
# |    fps                  | 974       |
# |    iterations           | 13        |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.2e+14   |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -4.03e-06 |
# |    reward               | 1006263.4 |
# |    reward_max           | 2850874.8 |
# |    reward_mean          | 1642025.4 |
# |    reward_min           | 911108.4  |
# |    std                  | 1         |
# |    value_loss           | 8.73e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2803993.452365938
# Sharpe:  0.8984143652911685
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.94e+09  |
# | time/                   |           |
# |    fps                  | 985       |
# |    iterations           | 14        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.12e+14  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -4.48e-06 |
# |    reward               | 1141883.5 |
# |    reward_max           | 2810712.5 |
# |    reward_mean          | 1565628.9 |
# |    reward_min           | 901561.2  |
# |    std                  | 1         |
# |    value_loss           | 8.19e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2626004.5860772273
# Sharpe:  0.8442309316432208
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.93e+09  |
# | time/                   |           |
# |    fps                  | 993       |
# |    iterations           | 15        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.84e+14  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -4.96e-06 |
# |    reward               | 1658211.1 |
# |    reward_max           | 2632249.2 |
# |    reward_mean          | 1587873.0 |
# |    reward_min           | 933326.4  |
# |    std                  | 1         |
# |    value_loss           | 7.56e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2831400.293158092
# Sharpe:  0.9058512627880807
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.93e+09  |
# | time/                   |           |
# |    fps                  | 993       |
# |    iterations           | 16        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.56e+14  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -4.56e-06 |
# |    reward               | 1788160.9 |
# |    reward_max           | 2836705.0 |
# |    reward_mean          | 1661773.2 |
# |    reward_min           | 915865.5  |
# |    std                  | 1         |
# |    value_loss           | 7.58e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2894391.826930093
# Sharpe:  0.9250043052658355
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.94e+09  |
# | time/                   |           |
# |    fps                  | 1000      |
# |    iterations           | 17        |
# |    time_elapsed         | 34        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.27e+14  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -3.78e-06 |
# |    reward               | 1697490.8 |
# |    reward_max           | 2899807.0 |
# |    reward_mean          | 1687464.0 |
# |    reward_min           | 921647.06 |
# |    std                  | 1         |
# |    value_loss           | 8.3e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2631793.9189014346
# Sharpe:  0.8479026297825487
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.93e+09  |
# | time/                   |           |
# |    fps                  | 999       |
# |    iterations           | 18        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.71e+14  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -3.72e-06 |
# |    reward               | 2609968.2 |
# |    reward_max           | 2659662.2 |
# |    reward_mean          | 1698400.2 |
# |    reward_min           | 912043.06 |
# |    std                  | 1         |
# |    value_loss           | 8.64e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2818071.3134684158
# Sharpe:  0.9048323588581687
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2899136.3138407115
# Sharpe:  0.9320043514512915
# =================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.76e+03   |
# |    ep_rew_mean          | 2.93e+09   |
# | time/                   |            |
# |    fps                  | 994        |
# |    iterations           | 19         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.0        |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -39.7      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.68e+14   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -4.09e-06  |
# |    reward               | 1017200.75 |
# |    reward_max           | 2904942.5  |
# |    reward_mean          | 1687034.8  |
# |    reward_min           | 922753.06  |
# |    std                  | 1          |
# |    value_loss           | 8.63e+14   |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2753759.947318013
# Sharpe:  0.8828522388495212
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.92e+09  |
# | time/                   |           |
# |    fps                  | 997       |
# |    iterations           | 20        |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.24e+14  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -4.22e-06 |
# |    reward               | 1138230.1 |
# |    reward_max           | 2758710.8 |
# |    reward_mean          | 1511755.6 |
# |    reward_min           | 905482.6  |
# |    std                  | 1         |
# |    value_loss           | 8.68e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2931048.6358900275
# Sharpe:  0.931548779275076
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.92e+09  |
# | time/                   |           |
# |    fps                  | 1003      |
# |    iterations           | 21        |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.29e+14  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -3.46e-06 |
# |    reward               | 1482299.1 |
# |    reward_max           | 2936753.8 |
# |    reward_mean          | 1602318.0 |
# |    reward_min           | 920017.56 |
# |    std                  | 1         |
# |    value_loss           | 7.04e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2764794.8769879923
# Sharpe:  0.8909878496036191
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.92e+09  |
# | time/                   |           |
# |    fps                  | 1008      |
# |    iterations           | 22        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 3.56e+14  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -3.92e-06 |
# |    reward               | 1636342.1 |
# |    reward_max           | 2769957.5 |
# |    reward_mean          | 1655856.0 |
# |    reward_min           | 920376.7  |
# |    std                  | 1         |
# |    value_loss           | 7.88e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2994901.30082298
# Sharpe:  0.9520934238760745
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.93e+09  |
# | time/                   |           |
# |    fps                  | 1015      |
# |    iterations           | 23        |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.02e+14  |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -2.67e-06 |
# |    reward               | 2077405.1 |
# |    reward_max           | 3001458.2 |
# |    reward_mean          | 1701008.6 |
# |    reward_min           | 899660.94 |
# |    std                  | 1         |
# |    value_loss           | 8.24e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2757899.1912462427
# Sharpe:  0.8896726040303531
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.92e+09  |
# | time/                   |           |
# |    fps                  | 1019      |
# |    iterations           | 24        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.73e+14  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -3.98e-06 |
# |    reward               | 2669119.5 |
# |    reward_max           | 2764110.2 |
# |    reward_mean          | 1744971.6 |
# |    reward_min           | 915607.6  |
# |    std                  | 1         |
# |    value_loss           | 8.82e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2855724.844803407
# Sharpe:  0.9134496143253332
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2721311.64582995
# Sharpe:  0.8690718847254585
# =================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.76e+03  |
# |    ep_rew_mean          | 2.92e+09  |
# | time/                   |           |
# |    fps                  | 1018      |
# |    iterations           | 25        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.00025   |
# |    loss                 | 4.42e+14  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -3.51e-06 |
# |    reward               | 1049700.1 |
# |    reward_max           | 2861889.5 |
# |    reward_mean          | 1688792.2 |
# |    reward_min           | 921206.3  |
# |    std                  | 1         |
# |    value_loss           | 9.14e+14  |
# ---------------------------------------
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:2851401.990377285
# Sharpe:  0.9152017053251496
# =================================
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
